# %% [markdown]
# train_test_split
# ================
# is a function from the scikit-learn library used to split arrays or matrices into random train and test subsets. It ensures that you evaluate your machine learning model on unseen data to prevent overfitting.
#
#
# The Better approach
# ===================
#
# 20,640 Houses
#
#         │
#         ▼
#
#  ┌───────────────┐
#  │               │
#  │               │
#  ▼               ▼
#
# Training Set    Testing Set
#
# 80%             20%
#
# 16,512          4,128
#
#
# Training vs Testing
# ===================
#
# Training Data
#
# ↓
#
# Learns Patterns
#
# ↓
#
# Testing Data
#
# ↓
#
# Measures Performance
#
#
#
# Golden Rule
# ===========
#
# The model should never see the test data during training.

# %% [markdown]
# How We Split the Data
# =====================
#
# Entire Dataset
#        │
#        ▼
#
# Features (X)      Target (y)
#        │              │
#        └──────┬───────┘
#               ▼
#
# train_test_split()
#
#               │
#    ┌──────────┴──────────┐
#    ▼                     ▼
#
# Training Set        Testing Set
#
# Learn Here          Evaluate Here
#
#
#
# New Important Concept: Data Leakage
# ===================================
#
# Data leakage happens when the model accidentally gets information it wouldn't have in the real world.
