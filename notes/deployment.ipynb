# %% [markdown]
# DEPLOYMENT
# ===========
#
# What is a .pkl File?
#
# Python has a library called pickle.
# Its job is to save Python objects.
#
# Scikit-learn recommends using joblib, which is optimized for models containing large NumPy arrays.
#
# Why Joblib?
# because it's faster and more efficient for machine learning models.
